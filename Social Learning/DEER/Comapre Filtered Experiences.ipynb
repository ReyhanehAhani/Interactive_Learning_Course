# %%
import gym
from collections import deque
import pickle
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np
from stable_baselines3 import DQN, PPO, A2C
import pygame
import threading
import time
import gym
from gym import spaces
import numpy as np
import pygame
import gym
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np
import random
import matplotlib.pyplot as plt
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))  # Convert states to numpy arrays for storage

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        # for b in batch:
            # print(b)
            # print(f'{(list(b[0]))}')
            # print(f'-{(list(b[1]))}')
            # print(f'-{(list(b[2]))}')
            # print(f'-{(list(b[3]))}')
            # print(f'-{(b[4])}-')
            # print(len(b[1]))
            # print(len(b[2]))
            # print(len(b[3]))
            # print(len(b[4]))
        state, action, reward, next_state, done = map(np.stack, zip(*batch))
        
        return torch.FloatTensor(state), torch.LongTensor(action), torch.FloatTensor(reward), torch.FloatTensor(next_state), torch.FloatTensor(done)

class PongEnvironment(gym.Env):
    def __init__(self):
        super(PongEnvironment, self).__init__()
        self.width = 400
        self.height = 300
        self.ball_radius = 10
        self.paddle_width = 10
        self.paddle_height = 60
        self.paddle_offset = 20
        self.ball_pos = np.array([self.width // 2, random.randint(0,self.height) // 2], dtype=float)
        self.ball_vel = np.array([5, 1], dtype=float) * 100
        self.paddle_pos = self.height // 2
        self.screen = pygame.display.set_mode((self.width, self.height))
        pygame.display.set_caption("Pong")

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(low=0, high=1, shape=(5,), dtype=np.float32)

    def reset(self):
        self.time_step=0
        self.start_time=time.time()
        self.tot_reward=0
        self.ball_pos = np.array([self.width // 2, self.height // random.randrange(1,10)], dtype=float)
        self.ball_vel = np.array([random.random(), random.random()], dtype=float) * 100
        self.paddle_pos = self.height // 2
        return self.get_state()

    def step(self, action):
        
        self.time_step+=1
        if action == 0:
            move = -5
        else:
            move = 5
        self.move_paddle(move)
        self.ball_pos += self.ball_vel

        if (
            self.ball_pos[1] <= self.ball_radius
            or self.ball_pos[1] >= self.height - self.ball_radius
        ):
            self.ball_vel[1] *= -1

        reward = 0
        done = False

        if self.ball_pos[0] <= self.paddle_width + self.ball_radius:
            if (
                self.paddle_pos - self.paddle_height / 2
                <= self.ball_pos[1]
                <= self.paddle_pos + self.paddle_height / 2
            ):
                self.ball_vel[0] *= -1
                reward = 1
                self.tot_reward+=1
            else:
                reward = 0
                done = True
        if self.tot_reward>10 or time.time()-self.start_time>30:
            if self.tot_reward>10:
                print('xxx')
            done = True
        if self.ball_pos[0] >= self.width - self.ball_radius - self.paddle_width:
            self.ball_vel[0] *= -1

        return self.get_state(), reward, done, {}

    def move_paddle(self, move):
        self.paddle_pos = np.clip(
            self.paddle_pos + move,
            self.paddle_height / 2,
            self.height - self.paddle_height / 2,
        )

    def get_state(self):
        return np.array(
            [
                self.ball_pos[0] / self.width,
                self.ball_pos[1] / self.height,
                self.ball_vel[0] / 100,
                self.ball_vel[1] / 100,
                self.paddle_pos / self.height,
            ]
        )

    def render(self, mode="rgb_array"):
        self.screen.fill((0, 0, 0))
        pygame.draw.rect(
            self.screen,
            (255, 255, 255),
            pygame.Rect(
                0,
                int(self.paddle_pos - self.paddle_height / 2),
                self.paddle_width,
                self.paddle_height,
            ),
        )
        pygame.draw.circle(
            self.screen,
            (255, 255, 255),
            (int(self.ball_pos[0]), int(self.ball_pos[1])),
            self.ball_radius,
        )
        pygame.display.update()

        if mode == "rgb_array":
            data = pygame.surfarray.array3d(pygame.display.get_surface())
            return np.transpose(data, (1, 0, 2))
        return np.transpose(data, (1, 0, 2))


class DQNAgent:
    def __init__(self, env):
        self.model = DQN("MlpPolicy", env, verbose=1)
        self.env=env

    def train(self, total_timesteps):
        self.model.learn(total_timesteps=total_timesteps)
    def calculate_expertise(self, num_episodes=100):
        total_rewards = 0
        total_rewards_list=[]
        for zz in range(num_episodes):
            obs = self.env.reset()
            done = False
            episode_reward = 0
            
            while not done and episode_reward<100:
                action, _ = self.model.predict(obs)
                obs, reward, done, _ = self.env.step(action)
                episode_reward += reward
            total_rewards += episode_reward
            # print(episode_reward)
            total_rewards_list.append(episode_reward)
            
        average_reward = total_rewards / num_episodes
        return average_reward,total_rewards_list


class PPOAgent:
    def __init__(self, env):
        self.model = PPO("MlpPolicy", env, verbose=1)
        self.env=env


    def train(self, total_timesteps):
        self.model.learn(total_timesteps=total_timesteps)
    def calculate_expertise(self, num_episodes=100):
        total_rewards = 0
        total_rewards_list=[]
        for zz in range(num_episodes):
            obs = self.env.reset()
            done = False
            episode_reward = 0
            
            while not done and total_rewards<100:
                action, _ = self.model.predict(obs)
                obs, reward, done, _ = self.env.step(action)
                episode_reward += reward

            total_rewards += episode_reward
            # print(episode_reward)
            total_rewards_list.append(episode_reward)
            print(zz)
            
        average_reward = total_rewards / num_episodes
        return average_reward,total_rewards_list


class A2CAgent:
    def __init__(self, env):
        self.model = A2C("MlpPolicy", env, verbose=1)
        self.env=env

    def train(self, total_timesteps):
        self.model.learn(total_timesteps=total_timesteps)
        
    def calculate_expertise(self, num_episodes=100):
        total_rewards = 0
        total_rewards_list=[]
        for zz in range(num_episodes):
            obs = self.env.reset()
            done = False
            episode_reward = 0
            
            while not done and episode_reward<100:
                action, _ = self.model.predict(obs)
                obs, reward, done, _ = self.env.step(action)
                episode_reward += reward

            total_rewards += episode_reward
            print(episode_reward)
            total_rewards_list.append(episode_reward)
            print(zz)
            
        average_reward = total_rewards / num_episodes
        return average_reward,total_rewards_list


env = DummyVecEnv([lambda: PongEnvironment()])

dqn_agent = DQNAgent(env)
ppo_agent = PPOAgent(env)
a2c_agent = A2CAgent(env)


total_timesteps = 100000
dqn_agent.train(total_timesteps)
ppo_agent.train(total_timesteps)
a2c_agent.train(total_timesteps)




expert_agents=[dqn_agent,ppo_agent,a2c_agent]
expert_agents_2=[ppo_agent,dqn_agent]

# %%
import random
import numpy as np
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import pygame



class PongEnvironment:
    def __init__(self, width=400, height=300):
        self.width = width
        self.height = height
        self.ball_radius = 10
        self.paddle_width = 10
        self.paddle_height = 60
        self.paddle_offset = 20
        self.ball_pos = np.array([self.width // 2, random.randint(0,self.height) // 2], dtype=float)
        self.ball_vel = np.array([0.03, 0.01], dtype=float) * 100
        self.paddle_pos = random.randint(0,self.height)
        self.screen = pygame.display.set_mode((self.width, self.height))

    def reset(self):
        self.start_time=time.time()
        self.total_reward=0
        self.ball_pos = np.array([self.width // 2, random.randint(0,self.height)], dtype=float)
        self.ball_vel = np.array([0.03, 0.01], dtype=float) * 100
        self.paddle_pos = random.randint(0,self.height)
        return torch.FloatTensor(self.get_state())

    def step(self, action):
        if action == 0:  # Move up
            move = -5
        else:  # Move down
            move = 5
        self.move_paddle(move)
        self.ball_pos += self.ball_vel

        if self.ball_pos[1] <= self.ball_radius or self.ball_pos[1] >= self.height - self.ball_radius:
            self.ball_vel[1] *= -1

        reward = 0
        done = False

        if self.ball_pos[0] <= self.paddle_width + self.ball_radius:
            if self.paddle_pos - self.paddle_height / 2 <= self.ball_pos[1] <= self.paddle_pos + self.paddle_height / 2:
                self.ball_vel[0] *= -1
                reward = 1
                self.total_reward+=1
            else:
                reward = 0
                done = True
        if self.total_reward>10 or time.time()-self.start_time>10:
            done=True
        if self.ball_pos[0] >= self.width - self.ball_radius - self.paddle_width:
            self.ball_vel[0] *= -1

        return torch.FloatTensor(self.get_state()), reward, done  # Return state as a tensor

    def move_paddle(self, move):
        self.paddle_pos = np.clip(self.paddle_pos + move, self.paddle_height / 2, self.height - self.paddle_height / 2)

    def get_state(self):
        return np.array([
            self.ball_pos[0] / self.width,
            self.ball_pos[1] / self.height,
            self.ball_vel[0] / 100,
            self.ball_vel[1] / 100,
            self.paddle_pos / self.height
        ])

    def render(self):
        self.screen.fill((0, 0, 0))
        pygame.draw.rect(self.screen, (255, 255, 255), pygame.Rect(0, int(self.paddle_pos - self.paddle_height / 2), self.paddle_width, self.paddle_height))
        pygame.draw.circle(self.screen, (255, 255, 255), (int(self.ball_pos[0]), int(self.ball_pos[1])), self.ball_radius)
        pygame.display.flip()

class DQN(nn.Module):
    def __init__(self, state_size, action_size, hidden_size=64):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, action_size)
        )

    def forward(self, x):
        return self.fc(x)


def train_dqn_2(env,env2,replay_buffer):
    replay_buffer = ReplayBuffer(capacity=100_000)
    
    ACTION_SPACE = [0, 1]

    state_size = env.get_state().shape[0]
    action_size = len(ACTION_SPACE)
    hidden_size = 64
    batch_size = 256
    policy_net = DQN(state_size, action_size, hidden_size)
    target_net = DQN(state_size, action_size, hidden_size)
    target_net.load_state_dict(policy_net.state_dict())
    target_net.eval()
    optimizer = optim.Adam(policy_net.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    epsilon_start = 1.0
    epsilon_end = 0.01
    epsilon_decay = 0.995
    epsilon = epsilon_start

    rewards_per_episode = []
    losses = []
    avg_hit=0
    for episode in range(200):
        state = env.reset()
        total_reward = 0
        done = False
        episode_losses = []
        avg_hit=sum(rewards_per_episode)/(len(rewards_per_episode)+1)

        if not episode%5:
                for expert_agent in expert_agents:
                    obs_t = env2.reset()
                    done_t=False
                    for _ in range(1000):  # Collect 1000 steps from each expert
                        action_t, __t = expert_agent.model.predict(obs_t)
                        new_obs_t, reward_t, done_t = env2.step(action_t)
                        state_transformed=np.array([np.array(obs_t.detach().numpy())][0]).reshape(1, -1)

                        next_state_transformed=np.array([np.array(new_obs_t.detach().numpy())][0]).reshape(1, -1)
                        # print(state_transformed)
                        # obs, action, reward, new_obs, float(done))
                        # print(state.shape())
                        replay_buffer.add(state_transformed, [action_t], [reward_t], next_state_transformed, float(done_t))

                        # replay_buffer.add(obs_t, action_t, reward_t, new_obs_t, float(done_t))
                        obs_t = new_obs_t
                        if done_t:
                            obs_t = env2.reset()
            # else:
            #     print('here')
            #     for _ in range(1000):  # Collect 1000 steps from each expert
            #             epsilon = max(epsilon_end, epsilon_decay * epsilon)
            #             if random.random() > epsilon:
            #                 with torch.no_grad():
            #                     state_t = state.unsqueeze(0)
            #                     action_values = policy_net(state_t)
            #                     action = ACTION_SPACE[action_values.max(1)[1].item()]
            #             else:
            #                 action = random.choice(ACTION_SPACE)

            #             next_state, reward, done = env.step(action)
            #             replay_buffer.add(next_state, [action], [reward], next_state, float(done))
                        

            #             state = next_state
            #             total_reward += reward
                
            

        while not done and total_reward<10:
            epsilon = max(epsilon_end, epsilon_decay * epsilon)
            if random.random() > epsilon:
                with torch.no_grad():
                    state_t = state.unsqueeze(0)
                    action_values = policy_net(state_t)
                    action = ACTION_SPACE[action_values.max(1)[1].item()]
            else:
                action = random.choice(ACTION_SPACE)

            next_state, reward, done = env.step(action)

            state = next_state
            total_reward += reward
            # print(total_reward)

        if (len(replay_buffer.buffer) > batch_size  and avg_hit<1.5):
                states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)
                # actions = actions.view(-1)
                # print("Actions shape: ", actions.shape)
                # print("Policy net output shape: ", policy_net(states).shape)
                # print("next_state_values shape: ", next_states.shape)
                # print("dones shape: ", dones.shape)
                # print("rewards shape: ", rewards.shape)

                actions = actions.view(-1, 1, 1)
                state_action_values = policy_net(states).gather(2, actions)
                dones = dones.unsqueeze(-1)


                # Perform gather operation
                # state_action_values = policy_net(states).gather(1, actions.unsqueeze(-1))
                # state_action_values = policy_net(states).gather(1, actions.view(-1, 1))
                next_state_values = target_net(next_states).max(1)[0].detach()
                expected_state_action_values = (next_state_values * 0.99 * (1 - dones)) + rewards

                loss = criterion(state_action_values, expected_state_action_values)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                episode_losses.append(loss.item())

        rewards_per_episode.append(total_reward)
        losses.append(np.mean(episode_losses) if episode_losses else 0)
        print(f'Episode {episode}, Total Reward: {total_reward}, Average Loss: {np.mean(episode_losses) if episode_losses else 0}')

        if episode % 10 == 0:
            target_net.load_state_dict(policy_net.state_dict())


    plt.figure(figsize=(10,5))
    plt.subplot(1, 2, 1)
    plt.plot(rewards_per_episode)
    plt.title('Rewards per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.savefig('rewards_per_episode.png')

    plt.figure(figsize=(10,5))
    plt.subplot(1, 2, 2)
    plt.plot(losses)
    plt.title('Loss per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Loss')
    plt.tight_layout()
    plt.savefig('loss_per_episode.png')

    return rewards_per_episode, losses, policy_net



def train_dqn(env,env2,replay_buffer):
    replay_buffer = ReplayBuffer(capacity=100_000)
    
    ACTION_SPACE = [0, 1]

    state_size = env.get_state().shape[0]
    action_size = len(ACTION_SPACE)
    hidden_size = 64
    batch_size = 256
    policy_net = DQN(state_size, action_size, hidden_size)
    target_net = DQN(state_size, action_size, hidden_size)
    target_net.load_state_dict(policy_net.state_dict())
    target_net.eval()
    optimizer = optim.Adam(policy_net.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    epsilon_start = 1.0
    epsilon_end = 0.01
    epsilon_decay = 0.995
    epsilon = epsilon_start

    rewards_per_episode = []
    losses = []
    avg_hit=0
    for episode in range(200):
        state = env.reset()
        total_reward = 0
        done = False
        episode_losses = []
        avg_hit=sum(rewards_per_episode)/(len(rewards_per_episode)+1)

        if not episode%5:
                for expert_agent in expert_agents:
                    obs_t = env2.reset()
                    done_t=False
                    for _ in range(1000):  # Collect 1000 steps from each expert
                        action_t, __t = expert_agent.model.predict(obs_t)
                        new_obs_t, reward_t, done_t = env2.step(action_t)
                        state_transformed=np.array([np.array(obs_t.detach().numpy())][0]).reshape(1, -1)

                        next_state_transformed=np.array([np.array(new_obs_t.detach().numpy())][0]).reshape(1, -1)
                        # print(state_transformed)
                        # obs, action, reward, new_obs, float(done))
                        # print(state.shape())
                        replay_buffer.add(state_transformed, [action_t], [reward_t], next_state_transformed, float(done_t))

                        # replay_buffer.add(obs_t, action_t, reward_t, new_obs_t, float(done_t))
                        obs_t = new_obs_t
                        if done_t:
                            obs_t = env2.reset()
            # else:
            #     print('here')
            #     for _ in range(1000):  # Collect 1000 steps from each expert
            #             epsilon = max(epsilon_end, epsilon_decay * epsilon)
            #             if random.random() > epsilon:
            #                 with torch.no_grad():
            #                     state_t = state.unsqueeze(0)
            #                     action_values = policy_net(state_t)
            #                     action = ACTION_SPACE[action_values.max(1)[1].item()]
            #             else:
            #                 action = random.choice(ACTION_SPACE)

            #             next_state, reward, done = env.step(action)
            #             replay_buffer.add(next_state, [action], [reward], next_state, float(done))
                        

            #             state = next_state
            #             total_reward += reward
                
            

        while not done and total_reward<10:
            epsilon = max(epsilon_end, epsilon_decay * epsilon)
            if random.random() > epsilon:
                with torch.no_grad():
                    state_t = state.unsqueeze(0)
                    action_values = policy_net(state_t)
                    action = ACTION_SPACE[action_values.max(1)[1].item()]
            else:
                action = random.choice(ACTION_SPACE)

            next_state, reward, done = env.step(action)

            state = next_state
            total_reward += reward
            # print(total_reward)

        if (len(replay_buffer.buffer) > batch_size ):
                states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)
                # actions = actions.view(-1)
                # print("Actions shape: ", actions.shape)
                # print("Policy net output shape: ", policy_net(states).shape)
                # print("next_state_values shape: ", next_states.shape)
                # print("dones shape: ", dones.shape)
                # print("rewards shape: ", rewards.shape)

                actions = actions.view(-1, 1, 1)
                state_action_values = policy_net(states).gather(2, actions)
                dones = dones.unsqueeze(-1)


                # Perform gather operation
                # state_action_values = policy_net(states).gather(1, actions.unsqueeze(-1))
                # state_action_values = policy_net(states).gather(1, actions.view(-1, 1))
                next_state_values = target_net(next_states).max(1)[0].detach()
                expected_state_action_values = (next_state_values * 0.99 * (1 - dones)) + rewards

                loss = criterion(state_action_values, expected_state_action_values)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                episode_losses.append(loss.item())

        rewards_per_episode.append(total_reward)
        losses.append(np.mean(episode_losses) if episode_losses else 0)
        print(f'Episode {episode}, Total Reward: {total_reward}, Average Loss: {np.mean(episode_losses) if episode_losses else 0}')

        if episode % 10 == 0:
            target_net.load_state_dict(policy_net.state_dict())


    plt.figure(figsize=(10,5))
    plt.subplot(1, 2, 1)
    plt.plot(rewards_per_episode)
    plt.title('Rewards per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.savefig('rewards_per_episode.png')


    return rewards_per_episode, losses, policy_net



alls=[[],[]]
for _ in range(10):
    replay_buffer = ReplayBuffer(capacity=100_000)
    
    env = PongEnvironment()
    env2 = PongEnvironment()
    print(env)
    rewards, losses, trained_net = train_dqn(env,env2,replay_buffer)
    alls[0].append(rewards)
    replay_buffer = ReplayBuffer(capacity=100_000)
    
    env = PongEnvironment()
    env2 = PongEnvironment()
    print(env)
    rewards, losses, trained_net = train_dqn_2(env,env2,replay_buffer)
    alls.append(rewards)
# Out:
# <__main__.PongEnvironment object at 0x0000029803D11C90>
# Episode 0, Total Reward: 0, Average Loss: 0.03303426131606102
# Episode 1, Total Reward: 0, Average Loss: 0.020333673804998398
# Episode 2, Total Reward: 0, Average Loss: 0.016354883089661598
# Episode 3, Total Reward: 0, Average Loss: 0.01321112085133791
# Episode 4, Total Reward: 0, Average Loss: 0.011683009564876556
# Episode 5, Total Reward: 0, Average Loss: 0.010847048833966255
# Episode 6, Total Reward: 0, Average Loss: 0.01049717701971531
# Episode 7, Total Reward: 0, Average Loss: 0.010634709149599075
# Episode 8, Total Reward: 0, Average Loss: 0.010951485484838486
# Episode 9, Total Reward: 1, Average Loss: 0.015638573095202446
# Episode 10, Total Reward: 0, Average Loss: 0.012312696315348148
# Episode 11, Total Reward: 1, Average Loss: 0.0038632082287222147
# Episode 12, Total Reward: 0, Average Loss: 0.003676018211990595
# Episode 13, Total Reward: 0, Average Loss: 0.0035127338487654924
# Episode 14, Total Reward: 10, Average Loss: 0.0033482222352176905
# Episode 15, Total Reward: 1, Average Loss: 0.0027552617248147726
# Episode 16, Total Reward: 0, Average Loss: 0.0026513529010117054
# Episode 17, Total Reward: 1, Average Loss: 0.002190318424254656
# Episode 18, Total Reward: 0, Average Loss: 0.0020056921057403088
# Episode 19, Total Reward: 10, Average Loss: 0.005985993891954422
# Episode 20, Total Reward: 0, Average Loss: 0.0018557916628196836
# Episode 21, Total Reward: 0, Average Loss: 0.0005377120105549693
# Episode 22, Total Reward: 0, Average Loss: 0.0005623287288472056
# Episode 23, Total Reward: 0, Average Loss: 0.0006294390768744051
# Episode 24, Total Reward: 0, Average Loss: 0.0006677351193502545
# Episode 25, Total Reward: 0, Average Loss: 0.0007489027339033782
# Episode 26, Total Reward: 0, Average Loss: 0.0006724006962031126
# Episode 27, Total Reward: 0, Average Loss: 0.0006923171458765864
# Episode 28, Total Reward: 0, Average Loss: 0.0006572265410795808
# Episode 29, Total Reward: 0, Average Loss: 0.0006461861776188016
# Episode 30, Total Reward: 0, Average Loss: 0.0006424782914109528
# Episode 31, Total Reward: 0, Average Loss: 0.0006055661360733211
# Episode 32, Total Reward: 0, Average Loss: 0.0005738495383411646
# Episode 33, Total Reward: 0, Average Loss: 0.000502112612593919
# Episode 34, Total Reward: 0, Average Loss: 0.0004571230383589864
# Episode 35, Total Reward: 0, Average Loss: 0.00043048441875725985
# Episode 36, Total Reward: 0, Average Loss: 0.0004611429467331618
# Episode 37, Total Reward: 0, Average Loss: 0.0004551870806608349
# Episode 38, Total Reward: 0, Average Loss: 0.008318769745528698
# Episode 39, Total Reward: 0, Average Loss: 0.0004394416173454374
# Episode 40, Total Reward: 1, Average Loss: 0.00047915056347846985
# Episode 41, Total Reward: 0, Average Loss: 0.00021565778297372162
# Episode 42, Total Reward: 0, Average Loss: 0.00021466809266712517
# Episode 43, Total Reward: 1, Average Loss: 0.00022107610129751265
# Episode 44, Total Reward: 0, Average Loss: 0.00021384016145020723
# Episode 45, Total Reward: 0, Average Loss: 0.00019221374532207847
# Episode 46, Total Reward: 0, Average Loss: 0.00018525696941651404
# Episode 47, Total Reward: 0, Average Loss: 0.004019326530396938
# Episode 48, Total Reward: 0, Average Loss: 0.0001659693371038884
# Episode 49, Total Reward: 2, Average Loss: 0.004058687016367912
# Episode 50, Total Reward: 2, Average Loss: 0.00014803702651988715
# Episode 51, Total Reward: 0, Average Loss: 0.0001021932257572189
# Episode 52, Total Reward: 0, Average Loss: 0.0001009891857393086
# Episode 53, Total Reward: 0, Average Loss: 0.007790014147758484
# Episode 54, Total Reward: 0, Average Loss: 0.00011092404747614637
# Episode 55, Total Reward: 0, Average Loss: 0.00011046980216633528
# Episode 56, Total Reward: 0, Average Loss: 9.87352104857564e-05
# Episode 57, Total Reward: 0, Average Loss: 9.844772284850478e-05
# Episode 58, Total Reward: 0, Average Loss: 0.00010544499673414975
# Episode 59, Total Reward: 0, Average Loss: 0.003949949983507395
# Episode 60, Total Reward: 0, Average Loss: 9.487125498708338e-05
# Episode 61, Total Reward: 0, Average Loss: 9.59487515501678e-05
# Episode 62, Total Reward: 0, Average Loss: 9.196098108077422e-05
# Episode 63, Total Reward: 0, Average Loss: 7.581309182569385e-05
# Episode 64, Total Reward: 0, Average Loss: 9.115294960793108e-05
# Episode 65, Total Reward: 0, Average Loss: 7.681653369218111e-05
# Episode 66, Total Reward: 0, Average Loss: 8.421755046583712e-05
# Episode 67, Total Reward: 1, Average Loss: 8.062008419074118e-05
# Episode 68, Total Reward: 0, Average Loss: 7.702176662860438e-05
# Episode 69, Total Reward: 10, Average Loss: 8.755554881645367e-05
# Episode 70, Total Reward: 0, Average Loss: 8.198841533157974e-05
# Episode 71, Total Reward: 0, Average Loss: 5.6141376262530684e-05
# Episode 72, Total Reward: 10, Average Loss: 5.89390256209299e-05
# Episode 73, Total Reward: 0, Average Loss: 5.9355628764024004e-05
# Episode 74, Total Reward: 0, Average Loss: 5.681574111804366e-05
# Episode 75, Total Reward: 0, Average Loss: 4.916952457278967e-05
# Episode 76, Total Reward: 10, Average Loss: 5.483873246703297e-05
# Episode 77, Total Reward: 0, Average Loss: 5.2960524044465274e-05
# Episode 78, Total Reward: 1, Average Loss: 4.806020297110081e-05
# Episode 79, Total Reward: 0, Average Loss: 4.5757511543342844e-05
# Episode 80, Total Reward: 0, Average Loss: 4.501261355471797e-05
# Episode 81, Total Reward: 0, Average Loss: 4.182241900707595e-05
# Episode 82, Total Reward: 0, Average Loss: 4.5349202991928905e-05
# Episode 83, Total Reward: 0, Average Loss: 4.282594454707578e-05
# Episode 84, Total Reward: 0, Average Loss: 4.2559295252431184e-05
# Episode 85, Total Reward: 0, Average Loss: 4.479808558244258e-05
# Episode 86, Total Reward: 2, Average Loss: 0.00392887881025672
# Episode 87, Total Reward: 0, Average Loss: 4.435146911418997e-05
# Episode 88, Total Reward: 0, Average Loss: 4.388618253869936e-05
# Episode 89, Total Reward: 1, Average Loss: 3.582368299248628e-05
# Episode 90, Total Reward: 0, Average Loss: 3.923283293261193e-05
# Episode 91, Total Reward: 0, Average Loss: 3.9104492316255346e-05
# Episode 92, Total Reward: 0, Average Loss: 3.451387965469621e-05
# Episode 93, Total Reward: 0, Average Loss: 3.0375082133105025e-05
# Episode 94, Total Reward: 0, Average Loss: 3.361506969667971e-05
# Episode 95, Total Reward: 0, Average Loss: 3.4125117963412777e-05
# Episode 96, Total Reward: 0, Average Loss: 3.3535321563249454e-05
# Episode 97, Total Reward: 0, Average Loss: 3.268598084105179e-05
# Episode 98, Total Reward: 0, Average Loss: 3.589939296944067e-05
# Episode 99, Total Reward: 0, Average Loss: 0.0038974368944764137
# Episode 100, Total Reward: 0, Average Loss: 3.625512181315571e-05
# Episode 101, Total Reward: 0, Average Loss: 2.9913771868450567e-05
# Episode 102, Total Reward: 0, Average Loss: 2.992338704643771e-05
# Episode 103, Total Reward: 0, Average Loss: 3.072095933021046e-05
# Episode 104, Total Reward: 0, Average Loss: 3.464487599558197e-05
# Episode 105, Total Reward: 0, Average Loss: 2.376026168349199e-05
# Episode 106, Total Reward: 1, Average Loss: 2.7548430807655677e-05
# Episode 107, Total Reward: 0, Average Loss: 2.5570549041731283e-05
# Episode 108, Total Reward: 0, Average Loss: 2.8709617254207842e-05
# Episode 109, Total Reward: 0, Average Loss: 2.9029210054432042e-05
# Episode 110, Total Reward: 0, Average Loss: 0.00393674336373806
# Episode 111, Total Reward: 0, Average Loss: 2.553804006311111e-05
# Episode 112, Total Reward: 0, Average Loss: 0.0038996075745671988
# Episode 113, Total Reward: 0, Average Loss: 2.772210973489564e-05
# Episode 114, Total Reward: 0, Average Loss: 3.316329821245745e-05
# Episode 115, Total Reward: 10, Average Loss: 3.281432145740837e-05
# Episode 116, Total Reward: 0, Average Loss: 0.0039128502830863
# Episode 117, Total Reward: 0, Average Loss: 3.118909080512822e-05
# Episode 118, Total Reward: 0, Average Loss: 2.587046765256673e-05
# Episode 119, Total Reward: 0, Average Loss: 2.8339840355329216e-05
# Episode 120, Total Reward: 0, Average Loss: 2.0863952158833854e-05
# Episode 121, Total Reward: 0, Average Loss: 2.567262708907947e-05
# Episode 122, Total Reward: 1, Average Loss: 1.844139478635043e-05
# Episode 123, Total Reward: 0, Average Loss: 2.2379126676241867e-05
# Episode 124, Total Reward: 2, Average Loss: 0.0039003565907478333
# Episode 125, Total Reward: 0, Average Loss: 2.0525620129774325e-05
# Episode 126, Total Reward: 0, Average Loss: 2.3602442524861544e-05
# Episode 127, Total Reward: 0, Average Loss: 1.8930670194095e-05
# Episode 128, Total Reward: 0, Average Loss: 1.9176519344910048e-05
# Episode 129, Total Reward: 0, Average Loss: 1.9577859347919002e-05
# Episode 130, Total Reward: 0, Average Loss: 1.9624352717073634e-05
# Episode 131, Total Reward: 0, Average Loss: 1.579469426360447e-05
# Episode 132, Total Reward: 0, Average Loss: 0.00391921354457736
# Episode 133, Total Reward: 0, Average Loss: 2.1047568225185387e-05
# Episode 134, Total Reward: 0, Average Loss: 0.003899684641510248
# Episode 135, Total Reward: 0, Average Loss: 2.1274852770147845e-05
# Episode 136, Total Reward: 0, Average Loss: 2.0889900042675436e-05
# Episode 137, Total Reward: 0, Average Loss: 1.989563497772906e-05
# Episode 138, Total Reward: 0, Average Loss: 2.1648442270816304e-05
# Episode 139, Total Reward: 0, Average Loss: 1.7596206816961057e-05
# Episode 140, Total Reward: 0, Average Loss: 1.8477077901479788e-05
# Episode 141, Total Reward: 0, Average Loss: 2.0731440599774942e-05
# Episode 142, Total Reward: 0, Average Loss: 1.8364653442404233e-05
# Episode 143, Total Reward: 0, Average Loss: 2.175332701881416e-05
# Episode 144, Total Reward: 0, Average Loss: 2.0539613615255803e-05
# Episode 145, Total Reward: 0, Average Loss: 1.7230186131200753e-05
# Episode 146, Total Reward: 0, Average Loss: 1.4669118172605522e-05
# Episode 147, Total Reward: 0, Average Loss: 1.42178296300699e-05
# Episode 148, Total Reward: 0, Average Loss: 1.7926637156051584e-05
# Episode 149, Total Reward: 0, Average Loss: 1.4184604879119433e-05
# Episode 150, Total Reward: 0, Average Loss: 0.0038898775819689035
# Episode 151, Total Reward: 0, Average Loss: 1.7309463146375492e-05
# Episode 152, Total Reward: 0, Average Loss: 2.0281073375372216e-05
# Episode 153, Total Reward: 0, Average Loss: 1.8999711755895987e-05
# Episode 154, Total Reward: 0, Average Loss: 2.3222857635119e-05
# Episode 155, Total Reward: 0, Average Loss: 1.8194499716628343e-05
# Episode 156, Total Reward: 0, Average Loss: 1.75629866134841e-05
# Episode 157, Total Reward: 0, Average Loss: 1.3312466762727126e-05
# Episode 158, Total Reward: 0, Average Loss: 1.5904774045338854e-05
# Episode 159, Total Reward: 0, Average Loss: 0.003930707462131977
# Episode 160, Total Reward: 0, Average Loss: 1.6288680853904225e-05
# Episode 161, Total Reward: 0, Average Loss: 1.7818818378145806e-05
# Episode 162, Total Reward: 0, Average Loss: 1.5683228411944583e-05
# Episode 163, Total Reward: 0, Average Loss: 1.6283844161080196e-05
# Episode 164, Total Reward: 0, Average Loss: 1.4920288776920643e-05
# Episode 165, Total Reward: 0, Average Loss: 1.2671171134570614e-05
# Episode 166, Total Reward: 0, Average Loss: 1.2712905117950868e-05
# Episode 167, Total Reward: 0, Average Loss: 1.236389834957663e-05
# Episode 168, Total Reward: 0, Average Loss: 1.8806344087352045e-05
# Episode 169, Total Reward: 0, Average Loss: 1.581545438966714e-05
# Episode 170, Total Reward: 0, Average Loss: 1.6009798855520785e-05
# Episode 171, Total Reward: 0, Average Loss: 1.47849405038869e-05
# Episode 172, Total Reward: 0, Average Loss: 1.3420846698863897e-05
# Episode 173, Total Reward: 0, Average Loss: 1.340374456049176e-05
# Episode 174, Total Reward: 0, Average Loss: 1.2284937838558108e-05
# Episode 175, Total Reward: 0, Average Loss: 1.4751547496416606e-05
# Episode 176, Total Reward: 0, Average Loss: 1.0455453775648493e-05
# Episode 177, Total Reward: 0, Average Loss: 1.668013646849431e-05
# Episode 178, Total Reward: 0, Average Loss: 1.4784964150749147e-05
# Episode 179, Total Reward: 0, Average Loss: 1.1329440894769505e-05
# Episode 180, Total Reward: 0, Average Loss: 1.3448938261717558e-05
# Episode 181, Total Reward: 0, Average Loss: 1.4383213965629693e-05
# Episode 182, Total Reward: 0, Average Loss: 0.003918925765901804
# Episode 183, Total Reward: 0, Average Loss: 1.6389576558140106e-05
# Episode 184, Total Reward: 0, Average Loss: 1.576014983584173e-05
# Episode 185, Total Reward: 0, Average Loss: 1.785674612619914e-05
# Episode 186, Total Reward: 0, Average Loss: 1.9777187844738364e-05
# Episode 187, Total Reward: 0, Average Loss: 1.2518173207354266e-05
# Episode 188, Total Reward: 0, Average Loss: 0.003892880864441395
# Episode 189, Total Reward: 0, Average Loss: 1.0627296433085576e-05
# Episode 190, Total Reward: 0, Average Loss: 9.04015814739978e-06
# Episode 191, Total Reward: 0, Average Loss: 1.1819813153124414e-05
# Episode 192, Total Reward: 0, Average Loss: 1.1971475032623857e-05
# Episode 193, Total Reward: 0, Average Loss: 1.0683683285606094e-05
# Episode 194, Total Reward: 0, Average Loss: 1.0984542313963175e-05
# Episode 195, Total Reward: 0, Average Loss: 9.845862223301083e-06
# Episode 196, Total Reward: 0, Average Loss: 1.8647097022039816e-05
# Episode 197, Total Reward: 0, Average Loss: 1.0145147825824097e-05
# Episode 198, Total Reward: 0, Average Loss: 8.91039780981373e-06
# Episode 199, Total Reward: 0, Average Loss: 9.809252333070617e-06
# <__main__.PongEnvironment object at 0x0000029800BF5290>
# Episode 0, Total Reward: 0, Average Loss: 0.03874749690294266
# Episode 1, Total Reward: 0, Average Loss: 0.025589266791939735
# Episode 2, Total Reward: 0, Average Loss: 0.0203193761408329
# Episode 3, Total Reward: 0, Average Loss: 0.017019761726260185
# Episode 4, Total Reward: 0, Average Loss: 0.014571541920304298
# Episode 5, Total Reward: 0, Average Loss: 0.014739717356860638
# Episode 6, Total Reward: 0, Average Loss: 0.01421432290226221
# Episode 7, Total Reward: 0, Average Loss: 0.014267699792981148
# Episode 8, Total Reward: 1, Average Loss: 0.015422613359987736
# Episode 9, Total Reward: 0, Average Loss: 0.015023717656731606
# Episode 10, Total Reward: 0, Average Loss: 0.015345931984484196
# Episode 11, Total Reward: 0, Average Loss: 0.005087711848318577
# Episode 12, Total Reward: 0, Average Loss: 0.004495430737733841
# Episode 13, Total Reward: 0, Average Loss: 0.004371576011180878
# Episode 14, Total Reward: 0, Average Loss: 0.004038104321807623
# Episode 15, Total Reward: 0, Average Loss: 0.0033467861358076334
# Episode 16, Total Reward: 0, Average Loss: 0.003653614316135645
# Episode 17, Total Reward: 1, Average Loss: 0.0030833748169243336
# Episode 18, Total Reward: 1, Average Loss: 0.002833153121173382
# Episode 19, Total Reward: 0, Average Loss: 0.0027726488187909126
# Episode 20, Total Reward: 0, Average Loss: 0.0025279177352786064
# Episode 21, Total Reward: 0, Average Loss: 0.0005664951168000698
# Episode 22, Total Reward: 0, Average Loss: 0.0005656848661601543
# Episode 23, Total Reward: 0, Average Loss: 0.0008950717165134847
# Episode 24, Total Reward: 0, Average Loss: 0.0009538388694636524
# Episode 25, Total Reward: 0, Average Loss: 0.000760914757847786
# Episode 26, Total Reward: 0, Average Loss: 0.0008111161878332496
# Episode 27, Total Reward: 0, Average Loss: 0.0009306701831519604
# Episode 28, Total Reward: 0, Average Loss: 0.0006964046042412519
# Episode 29, Total Reward: 0, Average Loss: 0.0009615876479074359
# Episode 30, Total Reward: 0, Average Loss: 0.0006732938345521688
# Episode 31, Total Reward: 0, Average Loss: 0.0006158807664178312
# Episode 32, Total Reward: 0, Average Loss: 0.0005137436091899872
# Episode 33, Total Reward: 0, Average Loss: 0.0004910798743367195
# Episode 34, Total Reward: 0, Average Loss: 0.0004536006599664688
# Episode 35, Total Reward: 0, Average Loss: 0.0004376891301944852
# Episode 36, Total Reward: 0, Average Loss: 0.0006222872762009501
# Episode 37, Total Reward: 1, Average Loss: 0.004393644630908966
# Episode 38, Total Reward: 1, Average Loss: 0.0005396671476773918
# Episode 39, Total Reward: 1, Average Loss: 0.00033560700831003487
# Episode 40, Total Reward: 0, Average Loss: 0.0004744885372929275
# Episode 41, Total Reward: 0, Average Loss: 0.00038970273453742266
# Episode 42, Total Reward: 0, Average Loss: 0.00026246620109304786
# Episode 43, Total Reward: 1, Average Loss: 0.0004790873499587178
# Episode 44, Total Reward: 1, Average Loss: 0.000663632876239717
# Episode 45, Total Reward: 0, Average Loss: 0.0002338687190786004
# Episode 46, Total Reward: 0, Average Loss: 0.0003255931078456342
# Episode 47, Total Reward: 0, Average Loss: 0.00041099797817878425
# Episode 48, Total Reward: 0, Average Loss: 0.00041908168350346386
# Episode 49, Total Reward: 0, Average Loss: 0.00038468639831990004
# Episode 50, Total Reward: 1, Average Loss: 0.000204512441996485
# Episode 51, Total Reward: 1, Average Loss: 0.00016563216922804713
# Episode 52, Total Reward: 0, Average Loss: 0.00025330198695883155
# Episode 53, Total Reward: 0, Average Loss: 6.97681462042965e-05
# Episode 54, Total Reward: 0, Average Loss: 0.00025956323952414095
# Episode 55, Total Reward: 0, Average Loss: 0.0001686743344180286
# Episode 56, Total Reward: 0, Average Loss: 0.00016640490503050387
# Episode 57, Total Reward: 0, Average Loss: 0.00017309020040556788
# Episode 58, Total Reward: 0, Average Loss: 0.0002550477220211178
# Episode 59, Total Reward: 0, Average Loss: 6.830549682490528e-05
# Episode 60, Total Reward: 0, Average Loss: 6.21181825408712e-05
# Episode 61, Total Reward: 0, Average Loss: 5.109898484079167e-05
# Episode 62, Total Reward: 0, Average Loss: 0.00014666130300611258
# Episode 63, Total Reward: 0, Average Loss: 0.004047623835504055
# Episode 64, Total Reward: 0, Average Loss: 0.00023264951596502215
# Episode 65, Total Reward: 0, Average Loss: 0.00023923174012452364
# Episode 66, Total Reward: 0, Average Loss: 4.8152229283005e-05
# Episode 67, Total Reward: 0, Average Loss: 0.000147608297993429
# Episode 68, Total Reward: 0, Average Loss: 0.00014560890849679708
# Episode 69, Total Reward: 0, Average Loss: 5.170725489733741e-05
# Episode 70, Total Reward: 0, Average Loss: 0.00033017026726156473
# Episode 71, Total Reward: 1, Average Loss: 0.00032243761233985424
# Episode 72, Total Reward: 1, Average Loss: 4.038790211779997e-05
# Episode 73, Total Reward: 0, Average Loss: 0.00040569869452156126
# Episode 74, Total Reward: 0, Average Loss: 3.7996709579601884e-05
# Episode 75, Total Reward: 0, Average Loss: 0.000305372552247718
# Episode 76, Total Reward: 0, Average Loss: 0.003934318199753761
# Episode 77, Total Reward: 0, Average Loss: 3.967212978750467e-05
# Episode 78, Total Reward: 0, Average Loss: 0.0002990872017107904
# Episode 79, Total Reward: 0, Average Loss: 0.0003090087848249823
# Episode 80, Total Reward: 0, Average Loss: 0.0002190605882788077
# Episode 81, Total Reward: 0, Average Loss: 0.0002076148084597662
# Episode 82, Total Reward: 0, Average Loss: 2.9524067940656096e-05
# Episode 83, Total Reward: 0, Average Loss: 0.00011832034942926839
# Episode 84, Total Reward: 0, Average Loss: 3.983129863627255e-05
# Episode 85, Total Reward: 0, Average Loss: 0.00012057350249961019
# Episode 86, Total Reward: 0, Average Loss: 3.5735829442273825e-05
# Episode 87, Total Reward: 0, Average Loss: 0.00011489811731735244
# Episode 88, Total Reward: 0, Average Loss: 3.559794640750624e-05
# Episode 89, Total Reward: 0, Average Loss: 0.00011692606494762003
# Episode 90, Total Reward: 0, Average Loss: 0.00037336983950808644
# Episode 91, Total Reward: 0, Average Loss: 0.003930952865630388
# Episode 92, Total Reward: 0, Average Loss: 0.00011208393698325381
# Episode 93, Total Reward: 0, Average Loss: 0.00011247974180150777
# Episode 94, Total Reward: 0, Average Loss: 0.00019331599469296634
# Episode 95, Total Reward: 0, Average Loss: 0.0002854904450941831
# Episode 96, Total Reward: 0, Average Loss: 3.278598887845874e-05
# Episode 97, Total Reward: 0, Average Loss: 0.00011460154928499833
# Episode 98, Total Reward: 0, Average Loss: 0.0001965110277524218
# Episode 99, Total Reward: 0, Average Loss: 0.0001948841381818056
# Episode 100, Total Reward: 0, Average Loss: 0.00027174281422048807
# Episode 101, Total Reward: 0, Average Loss: 0.0002786376280710101
# Episode 102, Total Reward: 0, Average Loss: 0.00019234925275668502
# Episode 103, Total Reward: 0, Average Loss: 2.209726517321542e-05
# Episode 104, Total Reward: 0, Average Loss: 2.5449544409639202e-05
# Episode 105, Total Reward: 0, Average Loss: 0.0001059382630046457
# Episode 106, Total Reward: 0, Average Loss: 2.5002111215144396e-05
# Episode 107, Total Reward: 0, Average Loss: 2.3325505026150495e-05
# Episode 108, Total Reward: 0, Average Loss: 0.00010325123730581254
# Episode 109, Total Reward: 0, Average Loss: 0.00018856233509723097
# Episode 110, Total Reward: 0, Average Loss: 2.2505766537506133e-05
# Episode 111, Total Reward: 0, Average Loss: 0.00010568400466581807
# Episode 112, Total Reward: 0, Average Loss: 2.2872258341521956e-05
# Episode 113, Total Reward: 0, Average Loss: 0.00010527957056183368
# Episode 114, Total Reward: 0, Average Loss: 2.2012780391378328e-05
# Episode 115, Total Reward: 0, Average Loss: 2.480631519574672e-05
# Episode 116, Total Reward: 0, Average Loss: 0.00010419033060315996
# Episode 117, Total Reward: 0, Average Loss: 2.5950634153559804e-05
# Episode 118, Total Reward: 0, Average Loss: 2.4924227545852773e-05
# Episode 119, Total Reward: 0, Average Loss: 2.2936770619708113e-05
# Episode 120, Total Reward: 0, Average Loss: 0.00010423693311167881
# Episode 121, Total Reward: 0, Average Loss: 0.004059887025505304
# Episode 122, Total Reward: 0, Average Loss: 2.0495343051152304e-05
# Episode 123, Total Reward: 0, Average Loss: 9.8385862656869e-05
# Episode 124, Total Reward: 0, Average Loss: 2.1874060621485114e-05
# Episode 125, Total Reward: 0, Average Loss: 0.000258518906775862
# Episode 126, Total Reward: 0, Average Loss: 2.7288795536151156e-05
# Episode 127, Total Reward: 0, Average Loss: 0.003887567203491926
# Episode 128, Total Reward: 0, Average Loss: 2.2485664885607548e-05
# Episode 129, Total Reward: 0, Average Loss: 0.00010154679330298677
# Episode 130, Total Reward: 0, Average Loss: 0.00010262095020152628
# Episode 131, Total Reward: 0, Average Loss: 0.0003397036052774638
# Episode 132, Total Reward: 0, Average Loss: 9.711572783999145e-05
# Episode 133, Total Reward: 0, Average Loss: 0.0001779479207471013
# Episode 134, Total Reward: 0, Average Loss: 9.921643504640087e-05
# Episode 135, Total Reward: 0, Average Loss: 1.7708794985082932e-05
# Episode 136, Total Reward: 0, Average Loss: 2.1231535356491804e-05
# Episode 137, Total Reward: 0, Average Loss: 0.0003312275803182274
# Episode 138, Total Reward: 0, Average Loss: 9.695615153759718e-05
# Episode 139, Total Reward: 0, Average Loss: 0.00025277119129896164
# Episode 140, Total Reward: 0, Average Loss: 0.00010019473120337352
# Episode 141, Total Reward: 0, Average Loss: 0.00017728617240209132
# Episode 142, Total Reward: 0, Average Loss: 9.460742876399308e-05
# Episode 143, Total Reward: 0, Average Loss: 0.00024675726308487356
# Episode 144, Total Reward: 0, Average Loss: 9.385435259900987e-05
# Episode 145, Total Reward: 0, Average Loss: 9.672243322711438e-05
# Episode 146, Total Reward: 0, Average Loss: 2.0673194740084e-05
# Episode 147, Total Reward: 0, Average Loss: 0.00032222538720816374
# Episode 148, Total Reward: 0, Average Loss: 9.708099241834134e-05
# Episode 149, Total Reward: 0, Average Loss: 9.407494508195668e-05
# Episode 150, Total Reward: 0, Average Loss: 0.00016860659525264055
# Episode 151, Total Reward: 0, Average Loss: 9.003832383314148e-05
# Episode 152, Total Reward: 0, Average Loss: 0.00016664262511767447
# Episode 153, Total Reward: 0, Average Loss: 0.0001653856597840786
# Episode 154, Total Reward: 0, Average Loss: 9.003015293274075e-05
# Episode 155, Total Reward: 0, Average Loss: 0.004021923523396254
# Episode 156, Total Reward: 0, Average Loss: 0.00016245928418356925
# Episode 157, Total Reward: 0, Average Loss: 0.00016534165479242802
# Episode 158, Total Reward: 0, Average Loss: 0.00024035840760916471
# Episode 159, Total Reward: 0, Average Loss: 0.0002401601814199239
# Episode 160, Total Reward: 0, Average Loss: 0.003977406769990921
# Episode 161, Total Reward: 0, Average Loss: 0.00022862362675368786
# Episode 162, Total Reward: 0, Average Loss: 1.7392929294146597e-05
# Episode 163, Total Reward: 0, Average Loss: 0.00015775542124174535
# Episode 164, Total Reward: 0, Average Loss: 1.7467835277784616e-05
# Episode 165, Total Reward: 0, Average Loss: 0.00022535616881214082
# Episode 166, Total Reward: 0, Average Loss: 1.8394213839201257e-05
# Episode 167, Total Reward: 0, Average Loss: 1.7787950127967633e-05
# Episode 168, Total Reward: 0, Average Loss: 8.668869122629985e-05
# Episode 169, Total Reward: 0, Average Loss: 0.00015553270350210369
# Episode 170, Total Reward: 0, Average Loss: 1.8722605091170408e-05
# Episode 171, Total Reward: 0, Average Loss: 8.641273598186672e-05
# Episode 172, Total Reward: 0, Average Loss: 1.4684241250506602e-05
# Episode 173, Total Reward: 0, Average Loss: 1.6960764696705155e-05
# Episode 174, Total Reward: 0, Average Loss: 0.00022387831995729357
# Episode 175, Total Reward: 0, Average Loss: 1.3159853551769629e-05
# Episode 176, Total Reward: 0, Average Loss: 0.00021899993589613587
# Episode 177, Total Reward: 0, Average Loss: 8.317292667925358e-05
# Episode 178, Total Reward: 0, Average Loss: 0.000152082386193797
# Episode 179, Total Reward: 0, Average Loss: 8.289470133604482e-05
# Episode 180, Total Reward: 0, Average Loss: 0.00015104518388397992
# Episode 181, Total Reward: 0, Average Loss: 8.285622607218102e-05
# Episode 182, Total Reward: 0, Average Loss: 0.004013713449239731
# Episode 183, Total Reward: 0, Average Loss: 1.4348505828820635e-05
# Episode 184, Total Reward: 0, Average Loss: 8.020937821129337e-05
# Episode 185, Total Reward: 0, Average Loss: 1.85620356205618e-05
# Episode 186, Total Reward: 0, Average Loss: 1.9674616851261817e-05
# Episode 187, Total Reward: 0, Average Loss: 0.0002728201216086745
# Episode 188, Total Reward: 0, Average Loss: 8.210261876229197e-05
# Episode 189, Total Reward: 0, Average Loss: 1.3631513866130263e-05
# Episode 190, Total Reward: 0, Average Loss: 1.2206712199258618e-05
# Episode 191, Total Reward: 0, Average Loss: 1.27509338199161e-05
# Episode 192, Total Reward: 0, Average Loss: 0.00014937207743059844
# Episode 193, Total Reward: 0, Average Loss: 8.137636905303225e-05
# Episode 194, Total Reward: 0, Average Loss: 0.0002149935025954619
# Episode 195, Total Reward: 0, Average Loss: 0.0001461846986785531
# Episode 196, Total Reward: 0, Average Loss: 8.014733612071723e-05
# Episode 197, Total Reward: 0, Average Loss: 0.00014324227231554687
# Episode 198, Total Reward: 0, Average Loss: 0.0001426074159098789
# Episode 199, Total Reward: 0, Average Loss: 1.9232931663282216e-05
# <__main__.PongEnvironment object at 0x0000029803D10BD0>
# Episode 0, Total Reward: 0, Average Loss: 0.0029458797071129084
# Episode 1, Total Reward: 0, Average Loss: 0.0007008516695350409
# Episode 2, Total Reward: 0, Average Loss: 0.0011160639114677906
# Episode 3, Total Reward: 0, Average Loss: 0.0009747256408445537
# Episode 4, Total Reward: 0, Average Loss: 0.0007889735279604793
# Episode 5, Total Reward: 1, Average Loss: 0.0007489274721592665
# Episode 6, Total Reward: 0, Average Loss: 0.0007177984807640314
# Episode 7, Total Reward: 1, Average Loss: 0.000658464792650193
# Episode 8, Total Reward: 1, Average Loss: 0.0005610472871921957
# Episode 9, Total Reward: 0, Average Loss: 0.000618656340520829
# Episode 10, Total Reward: 0, Average Loss: 0.0006503862678073347
# Episode 11, Total Reward: 0, Average Loss: 0.0001156519865617156
# Episode 12, Total Reward: 0, Average Loss: 9.076517744688317e-05
# Episode 13, Total Reward: 0, Average Loss: 0.00011849671136587858
# Episode 14, Total Reward: 0, Average Loss: 0.00015402906865347177
# Episode 15, Total Reward: 0, Average Loss: 0.00015677725605200976
# Episode 16, Total Reward: 0, Average Loss: 0.00012302004324737936
# Episode 17, Total Reward: 0, Average Loss: 0.000127802777569741
# Episode 18, Total Reward: 0, Average Loss: 0.00010169990855501965
# Episode 19, Total Reward: 0, Average Loss: 0.00010324118920834735
# Episode 20, Total Reward: 0, Average Loss: 9.225868416251615e-05
# Episode 21, Total Reward: 0, Average Loss: 6.559537723660469e-05
# Episode 22, Total Reward: 0, Average Loss: 7.480860222131014e-05
# Episode 23, Total Reward: 0, Average Loss: 7.679715054109693e-05
# Episode 24, Total Reward: 0, Average Loss: 8.117813558783382e-05
# Episode 25, Total Reward: 0, Average Loss: 8.992657240014523e-05
# Episode 26, Total Reward: 0, Average Loss: 4.784998600371182e-05
# Episode 27, Total Reward: 0, Average Loss: 6.410389323718846e-05
# Episode 28, Total Reward: 10, Average Loss: 6.0930186009500176e-05
# Episode 29, Total Reward: 0, Average Loss: 8.139647252392024e-05
# Episode 30, Total Reward: 0, Average Loss: 6.072331962059252e-05
# Episode 31, Total Reward: 0, Average Loss: 4.280806388123892e-05
# Episode 32, Total Reward: 0, Average Loss: 2.6652998712961562e-05
# Episode 33, Total Reward: 0, Average Loss: 6.326689617708325e-05
# Episode 34, Total Reward: 0, Average Loss: 4.726818951894529e-05
# Episode 35, Total Reward: 0, Average Loss: 2.5454002752667293e-05
# Episode 36, Total Reward: 0, Average Loss: 4.646337038138881e-05
# Episode 37, Total Reward: 0, Average Loss: 7.815232675056905e-05
# Episode 38, Total Reward: 0, Average Loss: 4.378033190732822e-05
# Episode 39, Total Reward: 0, Average Loss: 3.6370925954543054e-05
# Episode 40, Total Reward: 0, Average Loss: 5.240149039309472e-05
# Episode 41, Total Reward: 0, Average Loss: 2.103076985804364e-05
# Episode 42, Total Reward: 0, Average Loss: 0.003933871164917946
# Episode 43, Total Reward: 0, Average Loss: 5.3258787374943495e-05
# Episode 44, Total Reward: 0, Average Loss: 2.9192207875894383e-05
# Episode 45, Total Reward: 0, Average Loss: 1.7392767404089682e-05
# Episode 46, Total Reward: 0, Average Loss: 3.199974889867008e-05
# Episode 47, Total Reward: 0, Average Loss: 1.997054641833529e-05
# Episode 48, Total Reward: 0, Average Loss: 2.745095844147727e-05
# Episode 49, Total Reward: 0, Average Loss: 2.9841326977475546e-05
# Episode 50, Total Reward: 0, Average Loss: 4.033074947074056e-05
# Episode 51, Total Reward: 0, Average Loss: 1.5222313777485397e-05
# Episode 52, Total Reward: 0, Average Loss: 2.646919892868027e-05
# Episode 53, Total Reward: 0, Average Loss: 0.003943395800888538
# Episode 54, Total Reward: 0, Average Loss: 1.2213165973662399e-05
# Episode 55, Total Reward: 0, Average Loss: 4.586648356053047e-05
# Episode 56, Total Reward: 0, Average Loss: 0.003936235327273607
# Episode 57, Total Reward: 0, Average Loss: 1.6922404029173777e-05
# Episode 58, Total Reward: 0, Average Loss: 0.0039065987803041935
# Episode 59, Total Reward: 0, Average Loss: 2.281975503137801e-05
# Episode 60, Total Reward: 0, Average Loss: 2.2785761757404543e-05
# Episode 61, Total Reward: 0, Average Loss: 3.157398896291852e-05
# Episode 62, Total Reward: 0, Average Loss: 1.480327955505345e-05
# Episode 63, Total Reward: 0, Average Loss: 4.3307656596880406e-05
# Episode 64, Total Reward: 0, Average Loss: 3.4763681469485164e-05
# Episode 65, Total Reward: 0, Average Loss: 0.003978362772613764
# Episode 66, Total Reward: 0, Average Loss: 1.4496446056000423e-05
# Episode 67, Total Reward: 0, Average Loss: 6.563587521668524e-05
# Episode 68, Total Reward: 0, Average Loss: 1.8829699911293574e-05
# Episode 69, Total Reward: 0, Average Loss: 0.0039480309933424
# Episode 70, Total Reward: 0, Average Loss: 2.251033038191963e-05
# Episode 71, Total Reward: 0, Average Loss: 3.3547177736181766e-05
# Episode 72, Total Reward: 0, Average Loss: 2.283717731188517e-05
# Episode 73, Total Reward: 0, Average Loss: 1.297135077038547e-05
# Episode 74, Total Reward: 1, Average Loss: 2.0695661078207195e-05
# Episode 75, Total Reward: 0, Average Loss: 6.190579006215557e-05
# Episode 76, Total Reward: 0, Average Loss: 0.003947747405618429
# Episode 77, Total Reward: 0, Average Loss: 1.655644337006379e-05
# Episode 78, Total Reward: 0, Average Loss: 0.003919432871043682
# Episode 79, Total Reward: 0, Average Loss: 0.003918196074664593
# Episode 80, Total Reward: 10, Average Loss: 4.129437729716301e-05
# Episode 81, Total Reward: 0, Average Loss: 1.4446210116147995e-05
# Episode 82, Total Reward: 0, Average Loss: 2.8326696337899193e-05
# Episode 83, Total Reward: 0, Average Loss: 3.7390720535768196e-05
# Episode 84, Total Reward: 0, Average Loss: 0.003931780811399221
# Episode 85, Total Reward: 0, Average Loss: 0.0039369272999465466
# Episode 86, Total Reward: 0, Average Loss: 0.003906091209501028
# Episode 87, Total Reward: 0, Average Loss: 7.920869393274188e-05
# Episode 88, Total Reward: 0, Average Loss: 4.938957863487303e-05
# Episode 89, Total Reward: 0, Average Loss: 4.9253641918767244e-05
# Episode 90, Total Reward: 0, Average Loss: 5.276894080452621e-05
# Episode 91, Total Reward: 0, Average Loss: 4.511878069024533e-05
# Episode 92, Total Reward: 0, Average Loss: 3.080066016991623e-05
# Episode 93, Total Reward: 0, Average Loss: 4.559554872685112e-05
# Episode 94, Total Reward: 0, Average Loss: 5.14284911332652e-05
# Episode 95, Total Reward: 0, Average Loss: 5.342888107406907e-05
# Episode 96, Total Reward: 0, Average Loss: 4.2339535866631195e-05
# Episode 97, Total Reward: 0, Average Loss: 1.796071774151642e-05
# Episode 98, Total Reward: 0, Average Loss: 3.416504478082061e-05
# Episode 99, Total Reward: 0, Average Loss: 4.74682601634413e-05
# Episode 100, Total Reward: 0, Average Loss: 3.0356430215761065e-05
# Episode 101, Total Reward: 0, Average Loss: 0.003918401896953583
# Episode 102, Total Reward: 0, Average Loss: 2.648494228196796e-05
# Episode 103, Total Reward: 0, Average Loss: 2.0511170077952556e-05
# Episode 104, Total Reward: 0, Average Loss: 3.777186429942958e-05
# Episode 105, Total Reward: 0, Average Loss: 3.847120751743205e-05
# Episode 106, Total Reward: 0, Average Loss: 1.5540457752649672e-05
# Episode 107, Total Reward: 0, Average Loss: 2.111748472088948e-05
# Episode 108, Total Reward: 0, Average Loss: 2.381789090577513e-05
# Episode 109, Total Reward: 1, Average Loss: 2.033141936408356e-05
# Episode 110, Total Reward: 0, Average Loss: 1.2617559150385205e-05
# Episode 111, Total Reward: 0, Average Loss: 8.083931788860355e-06
# Episode 112, Total Reward: 0, Average Loss: 6.6950342443306e-06
# Episode 113, Total Reward: 0, Average Loss: 7.347445716732182e-06
# Episode 114, Total Reward: 0, Average Loss: 0.003910180181264877
# Episode 115, Total Reward: 0, Average Loss: 3.014961475855671e-05
# Episode 116, Total Reward: 0, Average Loss: 3.464085966697894e-05
# Episode 117, Total Reward: 0, Average Loss: 1.8676773834158666e-05
# Episode 118, Total Reward: 0, Average Loss: 0.007845278829336166
# Episode 119, Total Reward: 0, Average Loss: 3.566183659131639e-05
# Episode 120, Total Reward: 0, Average Loss: 2.070780101348646e-05
# Episode 121, Total Reward: 0, Average Loss: 6.7054497776553035e-06
# Episode 122, Total Reward: 0, Average Loss: 7.31419277144596e-06
# Episode 123, Total Reward: 0, Average Loss: 4.0298240492120385e-05
# Episode 124, Total Reward: 0, Average Loss: 1.929709287651349e-05
# Episode 125, Total Reward: 0, Average Loss: 6.834454325144179e-06
# Episode 126, Total Reward: 0, Average Loss: 3.975386789534241e-05
# Episode 127, Total Reward: 0, Average Loss: 8.06418938736897e-06
# Episode 128, Total Reward: 2, Average Loss: 3.966103759012185e-05
# Episode 129, Total Reward: 0, Average Loss: 1.666368916630745e-05
# Episode 130, Total Reward: 0, Average Loss: 1.816891017369926e-05
# Episode 131, Total Reward: 0, Average Loss: 2.761818905128166e-05
# Episode 132, Total Reward: 0, Average Loss: 3.6548302887240425e-05
# Episode 133, Total Reward: 0, Average Loss: 0.003922032658010721
# Episode 134, Total Reward: 0, Average Loss: 1.0118714271811768e-05
# Episode 135, Total Reward: 0, Average Loss: 2.4051047148532234e-05
# Episode 136, Total Reward: 0, Average Loss: 1.9743863958865404e-05
# Episode 137, Total Reward: 0, Average Loss: 1.562622855999507e-05
# Episode 138, Total Reward: 1, Average Loss: 0.007880392484366894
# Episode 139, Total Reward: 0, Average Loss: 8.876078027242329e-06
# Episode 140, Total Reward: 0, Average Loss: 6.269429286476225e-05
# Episode 141, Total Reward: 0, Average Loss: 5.455435257317731e-06
# Episode 142, Total Reward: 0, Average Loss: 1.724598951113876e-05
# Episode 143, Total Reward: 0, Average Loss: 1.7196472981595434e-05
# Episode 144, Total Reward: 0, Average Loss: 0.003922043833881617
# Episode 145, Total Reward: 0, Average Loss: 0.0039118435233831406
# Episode 146, Total Reward: 0, Average Loss: 0.003912561107426882
# Episode 147, Total Reward: 0, Average Loss: 7.767171337036416e-05
# Episode 148, Total Reward: 0, Average Loss: 6.865517934784293e-05
# Episode 149, Total Reward: 0, Average Loss: 2.504393705748953e-05
# Episode 150, Total Reward: 0, Average Loss: 6.0700760514009744e-05
# Episode 151, Total Reward: 0, Average Loss: 3.179921623086557e-05
# Episode 152, Total Reward: 0, Average Loss: 1.7983138604904525e-05
# Episode 153, Total Reward: 0, Average Loss: 3.2771520636742935e-05
# Episode 154, Total Reward: 0, Average Loss: 1.8148972230846994e-05
# Episode 155, Total Reward: 0, Average Loss: 3.154245496261865e-05
# Episode 156, Total Reward: 0, Average Loss: 1.872017492132727e-05
# Episode 157, Total Reward: 1, Average Loss: 1.839630931499414e-05
# Episode 158, Total Reward: 1, Average Loss: 2.153449531760998e-05
# Episode 159, Total Reward: 0, Average Loss: 5.123382288729772e-05
# Episode 160, Total Reward: 0, Average Loss: 2.1146037397556938e-05
# Episode 161, Total Reward: 0, Average Loss: 4.164158781350125e-06
# Episode 162, Total Reward: 0, Average Loss: 1.391659134242218e-05
# Episode 163, Total Reward: 0, Average Loss: 6.285250492510386e-06
# Episode 164, Total Reward: 0, Average Loss: 6.570587174792308e-06
# Episode 165, Total Reward: 0, Average Loss: 0.007843922823667526
# Episode 166, Total Reward: 0, Average Loss: 2.2120115318102762e-05
# Episode 167, Total Reward: 0, Average Loss: 3.9701975765638053e-05
# Episode 168, Total Reward: 0, Average Loss: 3.3228250686079264e-05
# Episode 169, Total Reward: 0, Average Loss: 0.003926431760191917
# Episode 170, Total Reward: 0, Average Loss: 9.61711884883698e-06
# Episode 171, Total Reward: 0, Average Loss: 1.3323437087819912e-05
# Episode 172, Total Reward: 10, Average Loss: 1.5002485270088073e-05
# Episode 173, Total Reward: 0, Average Loss: 9.102812327910215e-06
# Episode 174, Total Reward: 0, Average Loss: 2.435837814118713e-05
# Episode 175, Total Reward: 0, Average Loss: 3.1565712561132386e-05
# Episode 176, Total Reward: 0, Average Loss: 1.480324863223359e-05
# Episode 177, Total Reward: 0, Average Loss: 2.16321277548559e-05
# Episode 178, Total Reward: 0, Average Loss: 2.280917215102818e-05
# Episode 179, Total Reward: 0, Average Loss: 3.4077362215612084e-05
# Episode 180, Total Reward: 0, Average Loss: 2.3481947209802456e-05
# Episode 181, Total Reward: 1, Average Loss: 2.1644025764544494e-05
# Episode 182, Total Reward: 0, Average Loss: 0.003933372907340527
# Episode 183, Total Reward: 0, Average Loss: 2.3607814000570215e-05
# Episode 184, Total Reward: 0, Average Loss: 6.961492545087822e-06
# Episode 185, Total Reward: 0, Average Loss: 1.2737553333863616e-05
# Episode 186, Total Reward: 0, Average Loss: 2.147266968677286e-05
# Episode 187, Total Reward: 0, Average Loss: 1.4490256035060156e-05
# Episode 188, Total Reward: 0, Average Loss: 1.3974628018331714e-05
# Episode 189, Total Reward: 0, Average Loss: 3.6437240851228125e-06
# Episode 190, Total Reward: 1, Average Loss: 2.283552566950675e-05
# Episode 191, Total Reward: 0, Average Loss: 6.531412054755492e-06
# Episode 192, Total Reward: 0, Average Loss: 0.003915022127330303
# Episode 193, Total Reward: 1, Average Loss: 1.76133617060259e-05
# Episode 194, Total Reward: 0, Average Loss: 0.0039090681821107864
# Episode 195, Total Reward: 1, Average Loss: 1.2825834346585907e-05
# Episode 196, Total Reward: 0, Average Loss: 8.275216714537237e-06
# Episode 197, Total Reward: 0, Average Loss: 4.096916381968185e-05
# Episode 198, Total Reward: 0, Average Loss: 1.0872981874854304e-05
# Episode 199, Total Reward: 0, Average Loss: 0.003932200372219086
# <__main__.PongEnvironment object at 0x000002980817EC50>
# Episode 0, Total Reward: 0, Average Loss: 0.0014269704697653651
# Episode 1, Total Reward: 0, Average Loss: 0.0016740511637181044
# Episode 2, Total Reward: 0, Average Loss: 0.0014638705179095268
# Episode 3, Total Reward: 10, Average Loss: 0.0013237306848168373
# Episode 4, Total Reward: 0, Average Loss: 0
# Episode 5, Total Reward: 0, Average Loss: 0
# Episode 6, Total Reward: 0, Average Loss: 0.0013097897171974182
# Episode 7, Total Reward: 0, Average Loss: 0.0012036506086587906
# Episode 8, Total Reward: 0, Average Loss: 0.0012306617572903633
# Episode 9, Total Reward: 0, Average Loss: 0.0011152976658195257
# Episode 10, Total Reward: 0, Average Loss: 0.00116533855907619
# Episode 11, Total Reward: 0, Average Loss: 0.00019678402168210596
# Episode 12, Total Reward: 0, Average Loss: 0.0002091006317641586
# Episode 13, Total Reward: 0, Average Loss: 0.00018538346921559423
# Episode 14, Total Reward: 0, Average Loss: 0.00021531409583985806
# Episode 15, Total Reward: 0, Average Loss: 0.00024876196403056383
# Episode 16, Total Reward: 1, Average Loss: 0.00014293458661995828
# Episode 17, Total Reward: 1, Average Loss: 0.0002061265695374459
# Episode 18, Total Reward: 0, Average Loss: 0.0001868531689979136
# Episode 19, Total Reward: 0, Average Loss: 0.0001506323169451207
# Episode 20, Total Reward: 1, Average Loss: 0.0001456381578464061
# Episode 21, Total Reward: 0, Average Loss: 6.80048979120329e-05
# Episode 22, Total Reward: 1, Average Loss: 5.867789877811447e-05
# Episode 23, Total Reward: 0, Average Loss: 6.802280404372141e-05
# Episode 24, Total Reward: 1, Average Loss: 9.246054105460644e-05
# Episode 25, Total Reward: 1, Average Loss: 2.925828448496759e-05
# Episode 26, Total Reward: 0, Average Loss: 9.286401473218575e-05
# Episode 27, Total Reward: 0, Average Loss: 0.00011589236237341538
# Episode 28, Total Reward: 0, Average Loss: 8.540000271750614e-05
# Episode 29, Total Reward: 0, Average Loss: 6.0741713241441175e-05
# Episode 30, Total Reward: 0, Average Loss: 3.2977219234453514e-05
# Episode 31, Total Reward: 1, Average Loss: 4.600915053742938e-05
# Episode 32, Total Reward: 0, Average Loss: 7.383916090475395e-05
# Episode 33, Total Reward: 0, Average Loss: 4.542641909210943e-05
# Episode 34, Total Reward: 0, Average Loss: 0.00012008508201688528
# Episode 35, Total Reward: 0, Average Loss: 9.557414159644395e-05
# Episode 36, Total Reward: 0, Average Loss: 4.812936094822362e-05
# Episode 37, Total Reward: 0, Average Loss: 7.458792242687196e-05
# Episode 38, Total Reward: 0, Average Loss: 4.6097542508505285e-05
# Episode 39, Total Reward: 0, Average Loss: 1.5190787962637842e-05
# Episode 40, Total Reward: 0, Average Loss: 7.38177914172411e-05
# Episode 41, Total Reward: 0, Average Loss: 0.0001234918599948287
# Episode 42, Total Reward: 0, Average Loss: 1.1244832421652973e-05
# Episode 43, Total Reward: 0, Average Loss: 3.47130662703421e-05
# Episode 44, Total Reward: 0, Average Loss: 1.1437147804826964e-05
# Episode 45, Total Reward: 0, Average Loss: 1.1632866517174989e-05
# Episode 46, Total Reward: 0, Average Loss: 3.6552068195305765e-05
# Episode 47, Total Reward: 0, Average Loss: 0.003993880469352007
# Episode 48, Total Reward: 0, Average Loss: 3.633472806541249e-05
# Episode 49, Total Reward: 0, Average Loss: 6.660750659648329e-05
# Episode 50, Total Reward: 0, Average Loss: 3.905680205207318e-05
# Episode 51, Total Reward: 0, Average Loss: 3.488256334094331e-05
# Episode 52, Total Reward: 0, Average Loss: 3.5010194551432505e-05
# Episode 53, Total Reward: 0, Average Loss: 3.317122900625691e-05
# Episode 54, Total Reward: 0, Average Loss: 3.1403207685798407e-05
# Episode 55, Total Reward: 0, Average Loss: 5.900685937376693e-05
# Episode 56, Total Reward: 0, Average Loss: 1.0820227544172667e-05
# Episode 57, Total Reward: 0, Average Loss: 5.7710905821295455e-05
# Episode 58, Total Reward: 0, Average Loss: 4.328632257966092e-06
# Episode 59, Total Reward: 1, Average Loss: 7.850198016967624e-06
# Episode 60, Total Reward: 0, Average Loss: 3.2961281249299645e-05
# Episode 61, Total Reward: 0, Average Loss: 5.56960594622069e-06
# Episode 62, Total Reward: 0, Average Loss: 3.0033610528334975e-05
# Episode 63, Total Reward: 0, Average Loss: 0.0039933109655976295
# Episode 64, Total Reward: 0, Average Loss: 1.7188212950713933e-05
# Episode 65, Total Reward: 0, Average Loss: 4.471479041967541e-05
# Episode 66, Total Reward: 0, Average Loss: 3.5617631510831416e-05
# Episode 67, Total Reward: 0, Average Loss: 5.8635719142330345e-06
# Episode 68, Total Reward: 10, Average Loss: 0.007869990542531013
# Episode 69, Total Reward: 0, Average Loss: 5.578621494350955e-05
# Episode 70, Total Reward: 0, Average Loss: 7.190532051026821e-05
# Episode 71, Total Reward: 0, Average Loss: 5.479716128320433e-05
# Episode 72, Total Reward: 0, Average Loss: 8.988925401354209e-06
# Episode 73, Total Reward: 0, Average Loss: 9.698605572339147e-05
# Episode 74, Total Reward: 0, Average Loss: 3.3179188903886825e-05
# Episode 75, Total Reward: 0, Average Loss: 0.0039091710932552814
# Episode 76, Total Reward: 0, Average Loss: 1.2373189747449942e-05
# Episode 77, Total Reward: 0, Average Loss: 5.6449549447279423e-05
# Episode 78, Total Reward: 0, Average Loss: 9.77531453827396e-06
# Episode 79, Total Reward: 0, Average Loss: 0.003935442306101322
# Episode 80, Total Reward: 0, Average Loss: 2.9975723009556532e-05
# Episode 81, Total Reward: 1, Average Loss: 7.291958900168538e-05
# Episode 82, Total Reward: 0, Average Loss: 2.759342714853119e-05
# Episode 83, Total Reward: 0, Average Loss: 6.999195466050878e-05
# Episode 84, Total Reward: 0, Average Loss: 3.2402604119852185e-05
# Episode 85, Total Reward: 0, Average Loss: 7.00551099725999e-05
# Episode 86, Total Reward: 0, Average Loss: 5.0885105338238645e-06
# Episode 87, Total Reward: 0, Average Loss: 2.8698312235064805e-05
# Episode 88, Total Reward: 1, Average Loss: 2.9972430638736114e-05
# Episode 89, Total Reward: 0, Average Loss: 6.5606054704403505e-06
# Episode 90, Total Reward: 0, Average Loss: 9.073653927771375e-05
# Episode 91, Total Reward: 0, Average Loss: 2.577127088443376e-05
# Episode 92, Total Reward: 0, Average Loss: 6.698783636238659e-06
# Episode 93, Total Reward: 0, Average Loss: 2.737862268986646e-05
# Episode 94, Total Reward: 0, Average Loss: 2.7902900910703465e-05
# Episode 95, Total Reward: 0, Average Loss: 4.702413207269274e-06
# Episode 96, Total Reward: 0, Average Loss: 4.637893653125502e-06
# Episode 97, Total Reward: 0, Average Loss: 6.058189228497213e-06
# Episode 98, Total Reward: 0, Average Loss: 6.985702202655375e-05
# Episode 99, Total Reward: 0, Average Loss: 4.327166607254185e-06
# Episode 100, Total Reward: 0, Average Loss: 8.480963879264891e-05
# Episode 101, Total Reward: 0, Average Loss: 2.4684537493158132e-05
# Episode 102, Total Reward: 0, Average Loss: 2.31422673095949e-05
# Episode 103, Total Reward: 0, Average Loss: 2.511244747438468e-05
# Episode 104, Total Reward: 0, Average Loss: 4.2975145333912224e-05
# Episode 105, Total Reward: 0, Average Loss: 4.241159331286326e-05
# Episode 106, Total Reward: 0, Average Loss: 4.156484646955505e-05
# Episode 107, Total Reward: 0, Average Loss: 4.316938066040166e-05
# Episode 108, Total Reward: 0, Average Loss: 4.198741225991398e-05
# Episode 109, Total Reward: 0, Average Loss: 2.2610063751926646e-05
# Episode 110, Total Reward: 0, Average Loss: 3.682902388391085e-06
# Episode 111, Total Reward: 0, Average Loss: 2.2134894607006572e-05
# Episode 112, Total Reward: 0, Average Loss: 5.80429368710611e-05
# Episode 113, Total Reward: 0, Average Loss: 2.2039217583369464e-05
# Episode 114, Total Reward: 1, Average Loss: 2.3013493773760274e-05
# Episode 115, Total Reward: 0, Average Loss: 2.255090294056572e-05
# Episode 116, Total Reward: 0, Average Loss: 2.1228755940683186e-05
# Episode 117, Total Reward: 0, Average Loss: 3.838686097878963e-06
# Episode 118, Total Reward: 0, Average Loss: 2.29878569371067e-05
# Episode 119, Total Reward: 0, Average Loss: 7.777834980515763e-05
# Episode 120, Total Reward: 0, Average Loss: 7.567268767161295e-05
# Episode 121, Total Reward: 0, Average Loss: 3.7160629290156066e-05
# Episode 122, Total Reward: 0, Average Loss: 5.202006832405459e-06
# Episode 123, Total Reward: 0, Average Loss: 3.91969078918919e-05
# Episode 124, Total Reward: 0, Average Loss: 2.287524148414377e-05
# Episode 125, Total Reward: 0, Average Loss: 2.0232891984051093e-05
# Episode 126, Total Reward: 0, Average Loss: 3.1851236599322874e-06
# Episode 127, Total Reward: 0, Average Loss: 4.0455815906170756e-05
# Episode 128, Total Reward: 0, Average Loss: 2.216854045400396e-05
# ...
# Episode 158, Total Reward: 0, Average Loss: 8.339092346432153e-06
# Episode 159, Total Reward: 0, Average Loss: 8.352693839697167e-06
# Episode 160, Total Reward: 0, Average Loss: 8.30771659821039e-06
# Episode 161, Total Reward: 0, Average Loss: 5.506644811248407e-06
# Episode 162, Total Reward: 0, Average Loss: 6.597136234631762e-06
# Episode 163, Total Reward: 0, Average Loss: 7.5973057391820475e-06
# Episode 164, Total Reward: 0, Average Loss: 6.901084361743415e-06
# Episode 165, Total Reward: 0, Average Loss: 0.0038917534984648228
# Episode 166, Total Reward: 0, Average Loss: 6.372570624080254e-06
# Episode 167, Total Reward: 0, Average Loss: 8.090647497738246e-06
# Episode 168, Total Reward: 0, Average Loss: 9.549062269798014e-06
# Episode 169, Total Reward: 0, Average Loss: 1.0819938324857503e-05
# Episode 170, Total Reward: 0, Average Loss: 0.00391114316880703
# Episode 171, Total Reward: 0, Average Loss: 6.339460924209561e-06
# Episode 172, Total Reward: 0, Average Loss: 5.673613031831337e-06
# Episode 173, Total Reward: 0, Average Loss: 5.573041562456638e-06
# Episode 174, Total Reward: 0, Average Loss: 5.5127179621194955e-06
# Episode 175, Total Reward: 0, Average Loss: 5.599649739451706e-06
# Episode 176, Total Reward: 0, Average Loss: 5.518869329534937e-06
# Episode 177, Total Reward: 0, Average Loss: 5.228439931670437e-06
# Episode 178, Total Reward: 0, Average Loss: 6.081842457206221e-06
# Episode 179, Total Reward: 0, Average Loss: 5.3971884881320875e-06
# Episode 180, Total Reward: 0, Average Loss: 5.401977432484273e-06
# Episode 181, Total Reward: 0, Average Loss: 5.192688149691094e-06
# Episode 182, Total Reward: 0, Average Loss: 5.012334895582171e-06
# Episode 183, Total Reward: 0, Average Loss: 5.954175776423654e-06
# Episode 184, Total Reward: 0, Average Loss: 5.6466560636181384e-06
# Episode 185, Total Reward: 0, Average Loss: 5.288490683597047e-06
# Episode 186, Total Reward: 0, Average Loss: 5.7979727898782585e-06
# Episode 187, Total Reward: 0, Average Loss: 5.367836820369121e-06
# Episode 188, Total Reward: 0, Average Loss: 5.831826456415001e-06
# Episode 189, Total Reward: 0, Average Loss: 5.768184564658441e-06
# Episode 190, Total Reward: 0, Average Loss: 5.2281639000284486e-06
# Episode 191, Total Reward: 0, Average Loss: 6.053362085367553e-06
# Episode 192, Total Reward: 0, Average Loss: 4.8253450586344115e-06
# Episode 193, Total Reward: 0, Average Loss: 6.1061018641339615e-06
# Episode 194, Total Reward: 0, Average Loss: 5.371513907448389e-06
# Episode 195, Total Reward: 0, Average Loss: 5.426804364105919e-06
# Episode 196, Total Reward: 0, Average Loss: 5.228082045505289e-06
# Episode 197, Total Reward: 0, Average Loss: 5.788902399217477e-06
# Episode 198, Total Reward: 0, Average Loss: 5.9902922657784075e-06
# Episode 199, Total Reward: 0, Average Loss: 6.073556050978368e-06
# <__main__.PongEnvironment object at 0x000002980D549290>
# Episode 0, Total Reward: 0, Average Loss: 0.008839624933898449
# Episode 1, Total Reward: 0, Average Loss: 0.005857329815626144
# Episode 2, Total Reward: 5, Average Loss: 0.005105889402329922
# Episode 3, Total Reward: 0, Average Loss: 0.004908125847578049
# Episode 4, Total Reward: 0, Average Loss: 0.0012304288102313876
# Episode 5, Total Reward: 0, Average Loss: 0.0016145706176757812
# Episode 6, Total Reward: 0, Average Loss: 0.001521931728348136
# Episode 7, Total Reward: 0, Average Loss: 0.001583355595357716
# Episode 8, Total Reward: 0, Average Loss: 0.005277009680867195
# Episode 9, Total Reward: 0, Average Loss: 0.0010621428955346346
# Episode 10, Total Reward: 0, Average Loss: 0.0010654423385858536
# Episode 11, Total Reward: 1, Average Loss: 0.00017229284276254475
# Episode 12, Total Reward: 1, Average Loss: 0.00019535068713594228
# Episode 13, Total Reward: 0, Average Loss: 0.0002545963798183948
# Episode 14, Total Reward: 0, Average Loss: 0.00038832571590319276
# Episode 15, Total Reward: 0, Average Loss: 0.0004262761794961989
# Episode 16, Total Reward: 0, Average Loss: 0.00046590983401983976
# Episode 17, Total Reward: 0, Average Loss: 0.00030703566153533757
# Episode 18, Total Reward: 0, Average Loss: 0.00020549884357023984
# Episode 19, Total Reward: 0, Average Loss: 0.0001925842952914536
# Episode 20, Total Reward: 10, Average Loss: 0.00016748026246204972
# Episode 21, Total Reward: 1, Average Loss: 0.00013303800369612873
# Episode 22, Total Reward: 1, Average Loss: 0.00010451459093019366
# Episode 23, Total Reward: 0, Average Loss: 0.0040867142379283905
# Episode 24, Total Reward: 0, Average Loss: 0.0001653754588915035
# Episode 25, Total Reward: 1, Average Loss: 0.0002000828826567158
# Episode 26, Total Reward: 0, Average Loss: 0.00023177408729679883
# Episode 27, Total Reward: 0, Average Loss: 0.00017104283324442804
# Episode 28, Total Reward: 0, Average Loss: 0.0001272137596970424
# Episode 29, Total Reward: 1, Average Loss: 5.795681499876082e-05
# Episode 30, Total Reward: 0, Average Loss: 0.00010004639625549316
# Episode 31, Total Reward: 1, Average Loss: 3.339620161568746e-05
# Episode 32, Total Reward: 4, Average Loss: 0.00017587971524335444
# Episode 33, Total Reward: 0, Average Loss: 5.85364323342219e-05
# Episode 34, Total Reward: 0, Average Loss: 0.00014144086162559688
# Episode 35, Total Reward: 0, Average Loss: 0.00013773386308457702
# Episode 36, Total Reward: 0, Average Loss: 0.00020769602269865572
# Episode 37, Total Reward: 0, Average Loss: 0.0001231696514878422
# Episode 38, Total Reward: 6, Average Loss: 0.00011550194176379591
# Episode 39, Total Reward: 1, Average Loss: 0.00014692958211526275
# Episode 40, Total Reward: 0, Average Loss: 0.00010389967792434618
# Episode 41, Total Reward: 10, Average Loss: 7.371530227828771e-05
# Episode 42, Total Reward: 0, Average Loss: 0.00012125390639994293
# Episode 43, Total Reward: 10, Average Loss: 0.00015603449719492346
# Episode 44, Total Reward: 0, Average Loss: 0.00018971346435137093
# Episode 45, Total Reward: 1, Average Loss: 4.8820063966559246e-05
# Episode 46, Total Reward: 0, Average Loss: 0.003959086257964373
# Episode 47, Total Reward: 1, Average Loss: 4.175310459686443e-05
# Episode 48, Total Reward: 0, Average Loss: 0.003919530194252729
# Episode 49, Total Reward: 3, Average Loss: 0.00010316166299162433
# Episode 50, Total Reward: 1, Average Loss: 0.00010337094136048108
# Episode 51, Total Reward: 1, Average Loss: 6.075120472814888e-05
# Episode 52, Total Reward: 0, Average Loss: 0.00014080220717005432
# Episode 53, Total Reward: 0, Average Loss: 6.221907824510708e-05
# Episode 54, Total Reward: 10, Average Loss: 5.813207826577127e-05
# Episode 55, Total Reward: 0, Average Loss: 1.679316847003065e-05
# Episode 56, Total Reward: 2, Average Loss: 1.700147367955651e-05
# Episode 57, Total Reward: 0, Average Loss: 1.7183177988044918e-05
# Episode 58, Total Reward: 0, Average Loss: 9.149359539151192e-05
# Episode 59, Total Reward: 3, Average Loss: 5.5208616686286405e-05
# Episode 60, Total Reward: 0, Average Loss: 5.423034599516541e-05
# Episode 61, Total Reward: 1, Average Loss: 1.7466081771999598e-05
# Episode 62, Total Reward: 1, Average Loss: 0.00013010385737288743
# Episode 63, Total Reward: 0, Average Loss: 1.360150235996116e-05
# Episode 64, Total Reward: 2, Average Loss: 8.777587936492637e-05
# Episode 65, Total Reward: 3, Average Loss: 5.254805728327483e-05
# Episode 66, Total Reward: 1, Average Loss: 8.836889173835516e-05
# Episode 67, Total Reward: 1, Average Loss: 1.4348182958201505e-05
# Episode 68, Total Reward: 1, Average Loss: 8.760372293181717e-05
# Episode 69, Total Reward: 3, Average Loss: 8.963047730503604e-05
# Episode 70, Total Reward: 0, Average Loss: 1.3292074982018676e-05
# Episode 71, Total Reward: 0, Average Loss: 0.00012461535516195
# Episode 72, Total Reward: 1, Average Loss: 8.306208474095911e-05
# Episode 73, Total Reward: 1, Average Loss: 0.00012232671724632382
# Episode 74, Total Reward: 3, Average Loss: 1.6107462215586565e-05
# Episode 75, Total Reward: 1, Average Loss: 4.993385300622322e-05
# Episode 76, Total Reward: 2, Average Loss: 1.0231628039036877e-05
# Episode 77, Total Reward: 0, Average Loss: 4.86146382172592e-05
# Episode 78, Total Reward: 0, Average Loss: 1.0338328138459474e-05
# Episode 79, Total Reward: 0, Average Loss: 4.9658781790640205e-05
# Episode 80, Total Reward: 3, Average Loss: 1.0238748473057058e-05
# Episode 81, Total Reward: 0, Average Loss: 8.35027385619469e-05
# Episode 82, Total Reward: 1, Average Loss: 8.123712177621201e-05
# Episode 83, Total Reward: 10, Average Loss: 1.4674697013106197e-05
# Episode 84, Total Reward: 1, Average Loss: 1.46644388223649e-05
# Episode 85, Total Reward: 1, Average Loss: 0.00011719387111952528
# Episode 86, Total Reward: 1, Average Loss: 8.547726793040056e-06
# Episode 87, Total Reward: 0, Average Loss: 8.47690025693737e-05
# Episode 88, Total Reward: 0, Average Loss: 4.7073546738829464e-05
# Episode 89, Total Reward: 10, Average Loss: 0.00012047798372805119
# Episode 90, Total Reward: 0, Average Loss: 0.00011563863517949358
# Episode 91, Total Reward: 0, Average Loss: 0.00011382783122826368
# Episode 92, Total Reward: 1, Average Loss: 4.3622570956358686e-05
# Episode 93, Total Reward: 1, Average Loss: 8.059643005253747e-05
# Episode 94, Total Reward: 0, Average Loss: 4.961078229825944e-05
# Episode 95, Total Reward: 1, Average Loss: 7.71721315686591e-05
# Episode 96, Total Reward: 3, Average Loss: 4.2053379729622975e-05
# Episode 97, Total Reward: 0, Average Loss: 8.916163096728269e-06
# Episode 98, Total Reward: 0, Average Loss: 1.0433881470817141e-05
# Episode 99, Total Reward: 0, Average Loss: 0.003910357132554054
# Episode 100, Total Reward: 1, Average Loss: 4.3696127249859273e-05
# Episode 101, Total Reward: 10, Average Loss: 7.026197999948636e-05
# Episode 102, Total Reward: 0, Average Loss: 0.007744334638118744
# Episode 103, Total Reward: 0, Average Loss: 0.00011311584967188537
# Episode 104, Total Reward: 0, Average Loss: 0.00010998967627529055
# Episode 105, Total Reward: 1, Average Loss: 9.628861153032631e-05
# Episode 106, Total Reward: 10, Average Loss: 3.915388515451923e-05
# Episode 107, Total Reward: 1, Average Loss: 2.6206949769402854e-05
# Episode 108, Total Reward: 0, Average Loss: 8.567329496145248e-05
# Episode 109, Total Reward: 2, Average Loss: 0.00010376123827882111
# Episode 110, Total Reward: 3, Average Loss: 4.070391150889918e-05
# Episode 111, Total Reward: 0, Average Loss: 3.808012479566969e-05
# Episode 112, Total Reward: 0, Average Loss: 2.5012453988892958e-05
# Episode 113, Total Reward: 0, Average Loss: 4.124082988710143e-05
# Episode 114, Total Reward: 10, Average Loss: 8.144254388753325e-05
# Episode 115, Total Reward: 0, Average Loss: 1.1935155271203257e-05
# Episode 116, Total Reward: 0, Average Loss: 7.149857992772013e-05
# Episode 117, Total Reward: 1, Average Loss: 8.495672955177724e-05
# Episode 118, Total Reward: 0, Average Loss: 0.0001416397572029382
# Episode 119, Total Reward: 2, Average Loss: 3.888269202434458e-05
# Episode 120, Total Reward: 0, Average Loss: 6.784409924875945e-05
# Episode 121, Total Reward: 1, Average Loss: 3.316410584375262e-05
# Episode 122, Total Reward: 0, Average Loss: 3.674295294331387e-05
# Episode 123, Total Reward: 1, Average Loss: 6.235454202396795e-05
# Episode 124, Total Reward: 0, Average Loss: 1.2812480235879775e-05
# Episode 125, Total Reward: 1, Average Loss: 0.0039579132571816444
# Episode 126, Total Reward: 1, Average Loss: 1.0639914762577973e-05
# Episode 127, Total Reward: 0, Average Loss: 5.823670653626323e-05
# Episode 128, Total Reward: 1, Average Loss: 3.2871281291591004e-05
# Episode 129, Total Reward: 0, Average Loss: 6.587501957255881e-06
# Episode 130, Total Reward: 1, Average Loss: 7.317848030652385e-06
# Episode 131, Total Reward: 0, Average Loss: 5.943148789810948e-05
# Episode 132, Total Reward: 1, Average Loss: 5.699767370970221e-06
# Episode 133, Total Reward: 1, Average Loss: 6.050167030480225e-06
# Episode 134, Total Reward: 3, Average Loss: 5.7764846133068204e-05
# Episode 135, Total Reward: 1, Average Loss: 3.325374564155936e-05
# Episode 136, Total Reward: 1, Average Loss: 6.235654382180655e-06
# Episode 137, Total Reward: 0, Average Loss: 3.13314376398921e-05
# Episode 138, Total Reward: 3, Average Loss: 3.2539839594392106e-05
# Episode 139, Total Reward: 1, Average Loss: 5.927427991991863e-06
# Episode 140, Total Reward: 1, Average Loss: 8.477920346194878e-05
# Episode 141, Total Reward: 9, Average Loss: 5.67650276934728e-05
# Episode 142, Total Reward: 3, Average Loss: 5.083909854874946e-06
# Episode 143, Total Reward: 0, Average Loss: 3.257493153796531e-05
# Episode 144, Total Reward: 1, Average Loss: 6.6391735344950575e-06
# Episode 145, Total Reward: 1, Average Loss: 3.0205821531126276e-05
# Episode 146, Total Reward: 0, Average Loss: 5.684008647222072e-05
# Episode 147, Total Reward: 1, Average Loss: 5.773051088908687e-05
# Episode 148, Total Reward: 1, Average Loss: 5.609688378171995e-05
# Episode 149, Total Reward: 1, Average Loss: 5.5625154345761985e-05
# Episode 150, Total Reward: 0, Average Loss: 3.159698462695815e-05
# Episode 151, Total Reward: 10, Average Loss: 5.108990535518387e-06
# Episode 152, Total Reward: 0, Average Loss: 2.8679802198894322e-05
# Episode 153, Total Reward: 0, Average Loss: 2.9355074730119668e-05
# Episode 154, Total Reward: 0, Average Loss: 2.886302536353469e-05
# Episode 155, Total Reward: 0, Average Loss: 5.4533388720301446e-06
# Episode 156, Total Reward: 1, Average Loss: 4.202243417239515e-06
# Episode 157, Total Reward: 1, Average Loss: 4.024431746074697e-06
# Episode 158, Total Reward: 0, Average Loss: 4.8886449803831056e-06
# Episode 159, Total Reward: 0, Average Loss: 5.507997047971003e-05
# Episode 160, Total Reward: 0, Average Loss: 5.376127955969423e-05
# Episode 161, Total Reward: 1, Average Loss: 4.1909347601176705e-06
# Episode 162, Total Reward: 0, Average Loss: 2.719362237257883e-05
# Episode 163, Total Reward: 0, Average Loss: 9.754311759024858e-05
# Episode 164, Total Reward: 0, Average Loss: 7.880832527007442e-06
# Episode 165, Total Reward: 1, Average Loss: 2.9375984013313428e-05
# Episode 166, Total Reward: 3, Average Loss: 5.055186557001434e-05
# Episode 167, Total Reward: 1, Average Loss: 3.765031578950584e-06
# Episode 168, Total Reward: 0, Average Loss: 2.8514918085420504e-05
# Episode 169, Total Reward: 1, Average Loss: 2.784685420920141e-05
# Episode 170, Total Reward: 0, Average Loss: 2.7292438971926458e-05
# Episode 171, Total Reward: 0, Average Loss: 4.999522207072005e-05
# Episode 172, Total Reward: 0, Average Loss: 9.270543523598462e-05
# Episode 173, Total Reward: 0, Average Loss: 5.230052920524031e-05
# Episode 174, Total Reward: 1, Average Loss: 5.3510579164139926e-05
# Episode 175, Total Reward: 0, Average Loss: 2.7881247660843655e-05
# Episode 176, Total Reward: 1, Average Loss: 4.9408103222958744e-05
# Episode 177, Total Reward: 1, Average Loss: 9.876331023406237e-05
# Episode 178, Total Reward: 1, Average Loss: 2.7090709409094416e-05
# Episode 179, Total Reward: 3, Average Loss: 3.512239345582202e-06
# Episode 180, Total Reward: 0, Average Loss: 4.687701220973395e-06
# Episode 181, Total Reward: 0, Average Loss: 4.197872385702794e-06
# Episode 182, Total Reward: 0, Average Loss: 3.5392572499404196e-06
# Episode 183, Total Reward: 1, Average Loss: 3.2106731850944925e-06
# Episode 184, Total Reward: 0, Average Loss: 0.0038979416713118553
# Episode 185, Total Reward: 0, Average Loss: 7.164417911553755e-05
# Episode 186, Total Reward: 0, Average Loss: 3.682485476019792e-05
# Episode 187, Total Reward: 0, Average Loss: 9.123759082285687e-05
# Episode 188, Total Reward: 0, Average Loss: 2.6000881916843355e-05
# Episode 189, Total Reward: 2, Average Loss: 2.774005406536162e-05
# Episode 190, Total Reward: 1, Average Loss: 3.045325502171181e-05
# Episode 191, Total Reward: 1, Average Loss: 7.121224916772917e-05
# Episode 192, Total Reward: 0, Average Loss: 4.803664705832489e-05
# Episode 193, Total Reward: 2, Average Loss: 7.390326118184021e-06
# Episode 194, Total Reward: 0, Average Loss: 2.8529801056720316e-05
# Episode 195, Total Reward: 1, Average Loss: 2.5625860871514305e-05
# Episode 196, Total Reward: 1, Average Loss: 3.075150743825361e-06
# Episode 197, Total Reward: 0, Average Loss: 2.8289670808590017e-05
# Episode 198, Total Reward: 10, Average Loss: 2.7068927010986954e-05
# Episode 199, Total Reward: 1, Average Loss: 3.389203811821062e-06

# %%
print(len(alls))
new_alls = [alls[0], [alls[j] for j in range(1, 11)]]
alls_3 = []
for alls_1 in new_alls[0]:
    t = 0
    list_1 = []
    for i in range(200):
        t += alls_1[i]
        list_1.append(t / (i + 1))
    alls_3.append(list_1)
    rewards = alls_3
mean_regret = np.mean(rewards, axis=0)
std_regret = np.std(rewards, axis=0)

upper_bound = mean_regret + 1.96 * std_regret / np.sqrt(len(rewards))
lower_bound = mean_regret - 1.96 * std_regret / np.sqrt(len(rewards))

fig, ax = plt.subplots()
ax.plot(mean_regret, label="DQN-Filtered Experiences")
ax.fill_between(np.arange(len(mean_regret)), lower_bound, upper_bound, alpha=0.5)

alls_3 = []
for alls_1 in new_alls[1]:
    t = 0
    list_1 = []
    if len(alls_1) == 0:
        continue
    else:
        for i in range(200):
            t += alls_1[i]
            list_1.append(t / (i + 1))
        alls_3.append(list_1)
        rewards = alls_3
mean_regret = np.mean(rewards, axis=0)
std_regret = np.std(rewards, axis=0)

upper_bound = mean_regret + 1.96 * std_regret / np.sqrt(len(rewards))
lower_bound = mean_regret - 1.96 * std_regret / np.sqrt(len(rewards))


ax.plot(mean_regret, label="DQN-Not Filtered")
ax.fill_between(np.arange(len(mean_regret)), lower_bound, upper_bound, alpha=0.5)


ax.set_title(f"Avg hit count")
ax.set_xlabel("Episode")
ax.set_ylabel("average_hit_count")
ax.plot([0.304 for i in range(200)], label="Expected hit count for random agent")

plt.legend()

plt.show()
# Out:
# 12
